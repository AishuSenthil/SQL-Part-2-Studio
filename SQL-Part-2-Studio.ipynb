-- %% [markdown]
-- # Lesson 11: SQL Part 2 Studio
--
-- > This studio asks you to create queries using the functions from this lesson. As you work through the studio, you may need to create more than one query to return the desired answer.  For others, you may need to combine functions together in order to answer the original query.  The questions have been organized in a way to help you puzzle out the answers.
-- >
-- > Happy querying!
--
-- **The Dataset:**
--
-- > We will be working with the **BooksDB dataset** from Lesson 10.  You should already have access to it.

-- %% [markdown]
-- ## The Questions:

-- %% [markdown]
-- 1.  Create a query that returns the longest title in the dataset.  We can do this in two steps.
--
-- > A. Create a query that returns the length of the longest title.
-- >
-- > B. Create a query that uses the length you found in step A to find the longest title.

-- %%
-- Code here:
USE BooksDB
SELECT len(title) AS title_lenght FROM books
-- Out:
-- (10000 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00.261
-- <table><tr><th>title_lenght</th></tr><tr><td>39</td></tr><tr><td>56</td></tr><tr><td>23</td></tr><tr><td>21</td></tr><tr><td>16</td></tr><tr><td>22</td></tr><tr><td>10</td></tr><tr><td>22</td></tr><tr><td>37</td></tr><tr><td>19</td></tr><tr><td>15</td></tr><tr><td>25</td></tr><tr><td>4</td></tr><tr><td>11</td></tr><tr><td>25</td></tr><tr><td>48</td></tr><tr><td>36</td></tr><tr><td>59</td></tr><tr><td>54</td></tr><tr><td>33</td></tr><tr><td>60</td></tr><tr><td>16</td></tr><tr><td>58</td></tr><tr><td>54</td></tr><tr><td>55</td></tr><tr><td>38</td></tr><tr><td>57</td></tr><tr><td>17</td></tr><tr><td>16</td></tr><tr><td>9</td></tr><tr><td>8</td></tr><tr><td>15</td></tr><tr><td>19</td></tr><tr><td>39</td></tr><tr><td>13</td></tr><tr><td>25</td></tr><tr><td>64</td></tr><tr><td>24</td></tr><tr><td>46</td></tr><tr><td>15</td></tr><tr><td>57</td></tr><tr><td>31</td></tr><tr><td>9</td></tr><tr><td>31</td></tr><tr><td>10</td></tr><tr><td>19</td></tr><tr><td>14</td></tr><tr><td>14</td></tr><tr><td>23</td></tr><tr><td>23</td></tr><tr><td>42</td></tr><tr><td>22</td></tr><tr><td>34</td></tr><tr><td>75</td></tr><tr><td>15</td></tr><tr><td>28</td></tr><tr><td>23</td></tr><tr><td>34</td></tr><tr><td>15</td></tr><tr><td>49</td></tr><tr><td>21</td></tr><tr><td>43</td></tr><tr><td>7</td></tr><tr><td>17</td></tr><tr><td>18</td></tr><tr><td>19</td></tr><tr><td>18</td></tr><tr><td>24</td></tr><tr><td>31</td></tr><tr><td>25</td></tr><tr><td>31</td></tr><tr><td>12</td></tr><tr><td>28</td></tr><tr><td>23</td></tr><tr><td>18</td></tr><tr><td>41</td></tr><tr><td>21</td></tr><tr><td>17</td></tr><tr><td>5</td></tr><tr><td>49</td></tr><tr><td>11</td></tr><tr><td>17</td></tr><tr><td>16</td></tr><tr><td>13</td></tr><tr><td>20</td></tr><tr><td>33</td></tr><tr><td>15
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.296
-- <table><tr><th>title</th></tr><tr><td>Soccernomics: Why England Loses, Why Germany and Brazil Win, and Why the U.S., Japan, Australia, Turkey--and Even Iraq--Are Destined to Become the Kings of the World's Most Popular Sport</td></tr></table>

-- %% [markdown]
-- 2.  Use what you learned in question 1 to find the shortest author name.
--
-- > A. Create a query that returns the length of the shortest author.
-- >
-- > B. Create a query that returns the shortest author's name.

-- %%
-- Code here:
SELECT MIN(LEN(authors)) AS 'Min_auhtor' FROM BooksDB.dbo.books
SELECT (authors) FROM BooksDB.dbo.books
WHERE len(authors) = (SELECT MIN(LEN(authors))
FROM BooksDB.dbo.books)
-- Out:
-- (1 row affected)
-- (2 rows affected)
-- Total execution time: 00:00:00.489
-- <table><tr><th>Min_auhtor</th></tr><tr><td>3</td></tr></table>
-- <table><tr><th>authors</th></tr><tr><td>Avi</td></tr><tr><td>Avi</td></tr></table>

-- %% [markdown]
-- 3\. How many titles contain the word "The"?
--
--
--
-- > A. Is there a difference between the number of titles that use "The" or "the"?

-- %%
-- Code here:
SELECT count(title) FROM BooksDB.dbo.books
WHERE CHARINDEX ('the',title) > 0;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.478
-- <table><tr><th>(No column name)</th></tr><tr><td>4702</td></tr></table>

-- %% [markdown]
-- 4.  How many authors' names _start_ with 'Z'?

-- %%
-- Code here:
SELECT count(authors) FROM  BooksDB.dbo.books
WHERE authors LIKE 'Z%'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.192
-- <table><tr><th>(No column name)</th></tr><tr><td>11</td></tr></table>

-- %% [markdown]
-- 5\. How many books have been identified as printed in a language other than English?  There are four language codes for English: 'en', 'eng', 'en-US', and 'en-UK'.  Use LEFT to answer the question.  (Do not use the wildcard)
--
-- You might want to use one of these [comparison operators](https://docs.microsoft.com/en-us/sql/t-sql/language-elements/comparison-operators-transact-sql?view=sql-server-ver15).

-- %%
-- Code here:
SELECT COUNT(language_code) AS 'Number of books' FROM BooksDB.dbo.books
WHERE LEFT(language_code,2) != 'en'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.188
-- <table><tr><th>Number of books</th></tr><tr><td>186</td></tr></table>

-- %% [markdown]
-- 6\. Retry question 5 using SUBSTRING.

-- %%
-- Code here:
SELECT COUNT(language_code) AS 'number of books' FROM BooksDB.dbo.books
WHERE SUBSTRING(language_code,6,1)
-- Out:
-- : Msg 4145, Level 15, State 1, Line 3
-- An expression of non-boolean type specified in a context where a condition is expected, near ')'.
-- Total execution time: 00:00:00.415

-- %% [markdown]
-- 7.  Create a column that returns the title, authors, and language codes.  Concatenate these elements so that they return in the following way: title by authors in language\_code language.
--
-- > A.  Check each selected column to see where any values are NULL.  Did any of the columns contain NULL values?  If so, which one?

-- %%
-- Code here:
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.048

-- %% [markdown]
-- 8.  Update the query in question 7 using COALESCE to change the language code values from NULL to 'unknown'.
--
-- > A.  Has this changed the language\_code  where the values are NULL?

-- %%
-- Code here:
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.057

-- %% [markdown]
-- 9\. Revisit question 7 using ISNULL instead of COALESCE.
--
-- > A.  Has this changed the language\_code  where the values are NULL?

-- %%
-- Code here:
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.056
